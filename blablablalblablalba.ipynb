# %% [markdown]
# <a href="https://colab.research.google.com/github/ollihansen90/Mathe-SH/blob/main/blablablalblablalba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
from time import sleep

start = input('Enter zum starten tippen\n"Regeln" zum anzeigen der Regeln tippen\n\n')
clear_output()
if start.lower() == "regeln":
    input('Auf allen toten Felder mit drei bis sechs lebenden Nachbarn entsteht neues Leben. Eine lebendes Feld mit 0 oder 8 lebenden Nachbarn stirbt.\nEnter drücken um zu starten')
clear_output()

groesse = 20
anzahl = 20
bild = np.zeros([anzahl, groesse, groesse])
#bild[0, 10, 3] = 1
#bild[0, 10, 4] = 1
bild[0, 11, 3] = 1
bild[0, 11, 4] = 1
bild[0, 11, 5] = 1
bild_neu = bild.copy()
um_bild = np.zeros([22, 22])
#print(bild)

"""for k in range(20):
    for l in range(20):
        zwischenspeicher = bild[0, k, l].copy()
        #print(zwischenspeicher)
        #um_bild[k+1, l+1]
"""

for i in range(19):
    um_bild[1:groesse+1,1:groesse+1] = bild[i]
    for k in range(1, 21):
        for l in range(1, 21):
            lebendeNachbarn = 0 #um_bild[k-1, l-1]+um_bild[k-1, l]+um_bild[k-1, l+1]
            if um_bild[k-1, l-1] == 1:
                lebendeNachbarn += 1
            if um_bild[k-1, l] == 1:
                lebendeNachbarn += 1
            if um_bild[k-1, l+1] == 1:
                lebendeNachbarn += 1
            if um_bild[k, l-1] == 1:
                lebendeNachbarn += 1
            if um_bild[k, l+1] == 1:
                lebendeNachbarn += 1
            if um_bild[k+1, l-1] == 1:
                lebendeNachbarn += 1
            if um_bild[k+1, l] == 1:
                lebendeNachbarn += 1
            if um_bild[k+1, l+1] == 1:
                lebendeNachbarn += 1
            #print(lebendeNachbarn)
            if um_bild[k, l] == 0:
                if (lebendeNachbarn > 2):
                    bild_neu[i, k-1, l-1] = 1
            else:
                if (lebendeNachbarn > 3) or (lebendeNachbarn<2):
                    bild_neu[i, k-1, l-1] = 0
                """if lebendeNachbarn == 0:
                    bild_neu[i, k-1, l-1] = 0
                if lebendeNachbarn == 8:
                    bild_neu[i, k-1, l-1] = 0"""
    bild[i+1] = bild_neu[i]
                
    """
    clear_output()
    plt.figure()
    plt.imshow(bild[i])
    plt.show()"""
    #sleep(1)

plt.figure(figsize=[20,20])
for i in range(20):
    plt.subplot(4,5,i+1)
    plt.imshow(bild[i])
plt.show()
