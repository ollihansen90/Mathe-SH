# %% [markdown]
# <a href="https://colab.research.google.com/github/ollihansen90/Mathe-SH/blob/main/Prompt_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prompt-Engineering 🦾👷🏻

# %% [markdown]
# ## Fragen?
# Solltet ihr Fragen zum Code oder Probleme mit Colab haben, schickt uns gerne eine Mail:
#
# *   h.hansen@uni-luebeck.de
# *   mika.kohlhammer@student.uni-luebeck.de
# *   friederike.meissner@student.uni-luebeck.de
# *   dustin.haschke@student.uni-luebeck.de

# %% [markdown]
# Heute beschäftigen wir uns damit, wie wir einem Large Language Model (LLM) wie z.B. ChatGPT oder Gemini am besten vermitteln, was wir als Ausgabe erwarten, denn häufig entspricht die erste Antwort noch nicht unbedingt unseren Erwartungen.

# %% [markdown]
# ## Übersicht LLMs
#
#
#
# *   [OpenAI: ChatGPT](https://chatgpt.com/)
# *   [Google: Gemini](https://gemini.google.com/app)
# *   [Anthropic: Claude](https://claude.ai/)
# *   [Mistral: LeChat](https://mistral.ai/)
# *   [Microsoft: Copilot](https://copilot.microsoft.com/)

# %% [markdown]
# ## Empfehlungen
# ### Allgemein $\rightarrow$ konkret
#
# Zu Beginn startet man mit einer **groben Beschreibung** der Aufgabe bzw. Ausgangssituation und fügt dann immer mehr **Details** hinzu.
# Dafür lohnt es sich, sich anfangs ein paar Gedanken zum Zweck, dem Adressaten und den Qualitätsmerkmalen einer guten Antwort zu machen.

# %% [markdown]
# ### Beispiele
#
# Gebt Beispiele an, damit das LLM eine bessere Idee des Ziels bekommt.

# %% [markdown]
# ### Negative Prompts 🚫
#
# Formuliert explizit, was **nicht** in der Antwort enthalten bzw. nicht dafür verwendet werden soll.

# %% [markdown]
# ### Mehrere kleine Aufgaben statt einer großer Aufgabe
#
# Um eine umfangreiche/komplexe Aufgabe lösen zu lassen, sollte die Aufgabe in mehrere einfachere Teilaufgaben runtergebrochen werden.

# %% [markdown]
# ### Mehrdeutigkeiten vermeiden 🪢💧 🔐🏰 🐭🖱️ 🍐💡
#
# Mehrdeutige Formulierungen, v.a. beim Bezug auf vorhergehende Antworten, Dateien etc., sollte man vermeiden. Seid stattdessen so präzise wie möglich.

# %% [markdown]
# ### Englisch statt Deutsch
#
# Da LLMs im Training deutlich mehr englische als deutsche Texte "gesehen" haben, können Prompts auf Englisch zu besseren Ergebnissen führen. Wenn ihr euch noch unsicher mit englischen Formulierungen seid, könnt ihr euren Prompt und später auch die Antwort z.B. mit [DeepL](https://www.deepl.com/de/translator) übersetzen.

# %% [markdown]
# ### Mehrfach versuchen 🔄
#
# Häufig entspricht die erste generierte Antwort noch nicht eurer Erwartung, weil sie z.B. zu kurz oder zu allgemein ist. Dann kann es helfen, den Prompt etwas anzupassen und erneut ans LLM zu übergeben.

# %% [markdown]
# ### Wichtig
#
# Bleibt kritisch und hinterfragt die generierten Anworten, v.a. wenn es um Fakten geht!

# %% [markdown]
# ## ✨ Texte für das Text-Adventure generieren ✨
#
# Für unser Text-Adventure möchten wir nun mit Hilfe von LLMs Texte generieren lassen. Die Idee ist hierbei, dass wir durch Prompt-Engineering relativ einfach vorgeben können, was in dem Adventure passieren soll, und das entsprechende LLM schreibt uns den Text dazu.
#
# Stellen wir uns vor, wir haben eine Geschichte mit drei Entscheidungspunkten, bei denen wir jeweils vier mögliche Nachfolgepfade haben. Das ergibt $4\cdot4\cdot4=64$ Texte, die wir schreiben müssten (plus dem Einleitungstext, den wir jetzt ignorieren)! Das ist sehr viel Arbeit für gar nicht mal so viele Entscheidungspunkte.
#
# ### Die Mütze des Weihnachtsmanns 🎅
# Im Folgenden möchten wir gerne ein Text-Adventure zusammenstellen, um unser bisheriges Wissen zum Prompt-Engineering anzuwenden. Hierfür möchten wir gerne ein LLM nutzen.
#
# #### Schritt 1: Grobe Beschreibung der Geschichte 🤔
# Im ersten Schritt benötigen wir eine Rahmengeschichte, damit unser LLM weiß, worum es grob geht. Hierauf aufbauend können die einzelnen Texte geschrieben werden! Die Rahmengeschichte könnte folgendermaßen aussehen:
#
# > Der Weihnachtsmann hat seine Mütze verloren und sucht sie jetzt überall im Weihnachtsdorf. Es stellt sich am Ende heraus, dass er die Mütze in der Sauna abgelegt hat. Die Geschichte startet im Zuhause des Weihnachtsmanns, der seine Kleidung für Weihnachten waschen möchte. Hierbei fällt ihm auf, dass die Mütze fehlt. Sie endet in der Sauna, in der die Mütze liegt. Auf dem "Weg" durch unser Text-Adventure soll er mindestens zwei Stationen besuchen, die ihn in die Sauna führen. Weitere Stationen auf seiner Suche sind
# >- die Weihnachtsbäckerei (hier werden fleißig Kekse gebacken)
# >- die Weihnachtswerkstatt (für Geschenke)
# >- die Weihnachtsgarage (hier wird der Schlitten repariert)
# >- der Stall (hier sind die Rentiere)
# >- der Marktplatz des Weihnachtsdorfes (hier treffen sich die Bewohner für Veranstaltungen)
# >- die Wäscherei (hier wird die Kleidung gewaschen)
# >- der Tannenwald (ruhiger Ort am Rand des Dorfes, hier wohnen vor allem Tiere)
# >- die Kerzenzieherei (warmer Ort, an dem Kerzen hergestellt werden)
# >- die Weihnachtsbücherei (Bibliothek, in der Wunschzettel gesammelt oder die Weihnachtschroniken aufbewahrt werden)
# >- das Schneeflockenlabor (magischer Ort, an dem Schneeflockenmuster entworfen werden)
# >- der Rodelberg (kleiner Hügel, auf dem die Wichtel oder andere Dorfbewohner Schlitten fahren)
# >- ...
#
# Hieraus können wir nun unsere Geschichte aufbauen:

# %%
geschichte = {
    "Start": {"text": "", "pfade": [], "pfadtexte": []},
    "Weihnachtsbäckerei": {"text": "", "pfade":[], "pfadtexte":[]},
    "Weihnachtswerkstatt": {"text": "", "pfade":[], "pfadtexte":[]},
    "Weihnachtsgarage": {"text": "", "pfade":[], "pfadtexte":[]},
    "Stall": {"text": "", "pfade":[], "pfadtexte":[]},
    "Marktplatz": {"text": "", "pfade":[], "pfadtexte":[]},
    "Wäscherei": {"text": "", "pfade":[], "pfadtexte":[]},
    "Tannenwald": {"text": "", "pfade":[], "pfadtexte":[]},
    "Kerzenzieherei": {"text": "", "pfade":[], "pfadtexte":[]},
    "Weihnachtsbücherei": {"text": "", "pfade":[], "pfadtexte":[]},
    "Schneeflockenlabor": {"text": "", "pfade":[], "pfadtexte":[]},
    "Rodelberg": {"text": "", "pfade":[], "pfadtexte":[]},
    "Sauna": {"text": "", "pfade":[], "pfadtexte":[]},
}

# %% [markdown]
# #### Schritt 2: Pfade festlegen 🛷
# Häufig ist es sinnvoll, bereits vorher festzulegen, welche möglichen Nachfolger es für welche Station gibt. Der Vorteil ist so, dass wir sicherstellen können, dass jede Station besucht wird! Andernfalls kann es sein, dass wir unnötig viel Text generieren, der niemals gelesen wird. Wie *genau* die Pfade aussehen können, ist erstmal nicht so wichtig (das lässt sich später noch ändern/erweitern). Wichtig ist jedoch, dass wir nicht "im Kreis laufen" können. Hier ist es sinnvoll festzulegen, welche Station zu welchem Zeitpunkt besucht werden kann.
# - `t=0`: Start
# - `t=1`: Marktplatz, Tannenwald, Wäscherei
# - `t=2`: Stall, Rodelberg, Kerzenzieherei, Weihnachtsbücherei
# - `t=3`: Schneeflockenlabor, Weihnachtswerkstatt, Weihnachtsbäckerei, Weihnachtsgarage,
# - `t=4`: Sauna
#
# Die Nachfolger von allen Stationen bei `t=1` können nur aus der Menge bei `t=2` stammen. Wenn man sich geschickt mit der Formulierung anstellt, könnte man auch innerhalb eines Zeitpunktes "reisen". So kann der Leser alle Orte am Nordpol besuchen.

# %% [markdown]
# #### Schritt 3: Text für eine Station generieren 🎁
# Damit das LLM eine Geschichte zu einer Station entwickelt, müssen wir den Prompt zusammenstellen. Hierfür sollten wir möglichst viele Informationen mitliefern, damit wir möglichst wenig "selbst arbeiten" müssen. Ein möglicher Prompt könnte folgendermaßen aussehen:
#
# >Schreibe mir einen Textabschnitt für mein Text-Adventure, in dem der Weihnachtsmann seine Mütze verloren hat. Es gibt folgende Handlung:
# >
# >Der Weihnachtsmann hat seine Mütze verloren und sucht sie jetzt überall im Weihnachtsdorf. Es stellt sich am Ende heraus, dass er die Mütze in der Sauna abgelegt hat. Die Geschichte startet im Zuhause des Weihnachtsmanns, der seine Kleidung für Weihnachten waschen möchte. Hierbei fällt ihm auf, dass die Mütze fehlt. Sie endet in der Sauna, in der die Mütze liegt.
# >
# >Schreibe mir den Text zu der Station "Tannenwald". Der Tannenwald ist ein ruhiger Ort am Rande des Weihnachtsdorfes, in dem normalerweise die Tannen für Weihnachtsbäume gezüchtet werden. Die Tannen sind bereits gefällt worden, daher ist es sehr ruhig. Nur ein paar Tiere sind anwesend:
# >- Ein Eichhörnchen (hat die Mütze nicht gesehen, sucht gerade ein Versteck für eine Walnuss. Der Weihnachtsmann schlägt die Wurzeln eines umgefallenen Baumes vor.)
# >- Ein Reh (hat die Mütze nicht gesehen, erinnert sich aber an sie. Kennt das Rentier Rudolf. Schlägt einen Besuch im Stall vor.)
# >- Eine Eule (schläft, wacht auf, und ist etwas verärgert, dass sie geweckt wurde. Hat die Mütze nicht gesehen. Will sofort wieder schlafen gehen.)
# >- Ein Fuchs (hat die Mütze nicht gesehen, möchte aber auch so eine hübsche Mütze haben. Der Weihnachtsmann schlägt mit Augenzwinkern vor, dass er seinen Wunschzettel aktualisiert. Der Fuchs schlägt die Bibliothek vor.)
# >
# >Fasse dich bitte möglichst kurz (nicht mehr als 500 Wörter).
#
# Nimmt man diesen Prompt, wird folgender Text von ChatGPT generiert:

# %%
text = """Der Tannenwald liegt still vor dem Weihnachtsmann. Zwischen den Stümpfen der frisch gefällten Bäume raschelt nur gelegentlich der Schnee, und die wenigen Tiere hier scheinen genauso überrascht über seinen Besuch wie er über ihre Anwesenheit.

Ein Eichhörnchen huscht vor seinen Stiefeln vorbei, eine Walnuss zwischen den Pfoten. Auf seine Frage schüttelt es nur den Kopf – keine Mütze gesehen. „Aber ein Versteck fürs Nüsschen fehlt mir noch!“, fiept es. Der Weihnachtsmann deutet auf die weit verzweigten Wurzeln eines umgestürzten Baumes. Das Eichhörnchen strahlt, bedankt sich und verschwindet sofort darin.

Wenige Schritte weiter hebt ein Reh vorsichtig den Kopf. Es hat die Mütze ebenfalls nicht gesehen, erinnert sich aber dunkel daran, wie sie gestern Abend noch auf seinem Kopf saß. „Rudolf hat bestimmt auf dich gewartet“, sagt es und deutet mit einer sanften Kopfbewegung Richtung Stall.

Auf einem Ast darüber sitzt eine Eule, tief schlafend. Ein knirschender Tritt der Schneestiefel weckt sie. „Was… ist denn… jetzt?“ mürrt sie. Auch sie hat die Mütze nicht gesehen und ist viel zu müde, um weiterzuhelfen. Noch bevor der Weihnachtsmann ihr danken kann, steckt sie den Kopf wieder unter den Flügel und döst ein.

Schließlich taucht ein Fuchs zwischen zwei Sträuchern auf, neugierig und mit einem schelmischen Blick. Mütze? Nein, hat er nicht gesehen. „Aber eine hätte ich auch gern“, meint er und betrachtet des Weihnachtsmanns roten Mantel mit sichtbarer Begeisterung. Der Weihnachtsmann zwinkert. „Dann solltest du wohl deinen Wunschzettel noch einmal überarbeiten.“ Der Fuchs grinst breit. „Gute Idee! Und wenn du suchst – in der Bibliothek findet man immer Hinweise.“

Der Tannenwald bleibt ruhig zurück, während der Weihnachtsmann weiterzieht – ohne Mütze, aber mit mehreren neuen Hinweisen."""

# %% [markdown]
# #### Schritt 4: Geschichte erweitern 🦉🦊🐿️🦌
# Genau diesen Text müssen wir nun in unsere Geschichte einfügen. Wichtig hierbei ist, dass wir ebenfalls angeben, welche nächsten Stationen besucht werden, und wie die Auswahltexte hierfür aussehen.

# %%
geschichte["Tannenwald"]["text"] = text
geschichte["Tannenwald"]["pfade"] = ["Weihnachtsbücherei", "Stall"]
geschichte["Tannenwald"]["pfadtexte"] = ["Gehe in die Weihnachtsbücherei", "Besuche den Stall"]

# %% [markdown]
# #### Schritt 5: Schritte 3 und 4 wiederholen 🎄
# Zum Schluss müssen wir nur noch Schritte 2 und 3 wiederholen, bis alle unsere Stationen ausgeschrieben sind. Vieles ist bereits vorgegeben:
#
# >Schreibe mir einen Textabschnitt für mein Text-Adventure, in dem der Weihnachtsmann seine Mütze verloren hat. Es gibt folgende Handlung:
# >
# >Der Weihnachtsmann hat seine Mütze verloren und sucht sie jetzt überall im Weihnachtsdorf. Es stellt sich am Ende heraus, dass er die Mütze in der Sauna abgelegt hat. Die Geschichte startet im Zuhause des Weihnachtsmanns, der seine Kleidung für Weihnachten waschen möchte. Hierbei fällt ihm auf, dass die Mütze fehlt. Sie endet in der Sauna, in der die Mütze liegt.
# >
# >Schreibe mir den Text zu der Station **"Tannenwald". Der Tannenwald ist ein ruhiger Ort am Rande des Weihnachtsdorfes, in dem normalerweise die Tannen für Weihnachtsbäume gezüchtet werden. Die Tannen sind bereits gefällt worden, daher ist es sehr ruhig. Nur ein paar Tiere sind anwesend:**
# >- **Ein Eichhörnchen (hat die Mütze nicht gesehen, sucht gerade ein Versteck für eine Walnuss. Der Weihnachtsmann schlägt die Wurzeln eines umgefallenen Baumes vor.)**
# >- **Ein Reh (hat die Mütze nicht gesehen, erinnert sich aber an sie. Kennt das Rentier Rudolf. Schlägt einen Besuch im Stall vor.)**
# >- **Eine Eule (schläft, wacht auf, und ist etwas verärgert, dass sie geweckt wurde. Hat die Mütze nicht gesehen. Will sofort wieder schlafen gehen.)**
# >- **Ein Fuchs (hat die Mütze nicht gesehen, möchte aber auch so eine hübsche Mütze haben. Der Weihnachtsmann schlägt mit Augenzwinkern vor, dass er seinen Wunschzettel aktualisiert. Der Fuchs schlägt die Bibliothek vor.)**
# >
# >Fasse dich bitte möglichst kurz (nicht mehr als 500 Wörter).
#
# Hier müssen wir nur den fettgedruckten Text austauschen!
#
# ### ❄️ Aufgabe ❄️
# Such dir eine Station aus und überlege, was hier passieren soll. Passe den Prompt an, sodass der Text für die Station generiert wird. Erweitere die Geschichte `geschichte` um den Text und den entsprechenden Pfad.
