# %% [markdown]
# <a href="https://colab.research.google.com/github/ollihansen90/Mathe-SH/blob/main/Feigenbaum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Feigenbaum
# Um dynamische Systeme ein wenig besser zu verstehen, müssen wir zunächst die Hintereinanderausführung von Funktionen genauer betrachten. Hierfür definieren wir uns eine Funktion $f_r(x)=r\cdot x\cdot (1-x)$ und bilden bestimmte Iterierte in Abhängigkeit von $r\geq 0$ für ein beliebiges $x\in [0,1]$, um das sogenannte **Feigenbaumdiagramm** zu erhalten.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/7/7d/LogisticMap_BifurcationDiagram.png" width = "75%">
#
# ## Aufgabe 1:
# Schreibe ein Funktion, der man einen Wert $0\leq x\leq1$ und einen Parameter $0\leq r\leq4$ übergibt und die als Ausgabe den neuen $x$-Wert berechnet. Teste für unterschiedliche $r$-Werte und $x$-Eingaben den Verlauf der Pfade. Was fällt auf?
#
# Hinweis: Um einen Pfad zu zeichnen, kannst du zunächste mit `np.zeros(100)` eine Liste mit 100 Nullen erstellen. Überschreibe die allererste Null in der Liste mit deinem Startwert und berechne den darauffolgenden Wert mit der Funktion $f_r$.

# %%
import matplotlib.pyplot as plt
import numpy as np

pfad = np.zeros(100)
pfad[0] = 

# Hier startet deine For-Schleife für die Iterationen
for 

# Plotkrams
plt.figure()
plt.plot(pfad)
plt.grid()
plt.show()

# %% [markdown]
# ## Aufgabe 2:
# Plotte nun das Feigenbaumdiagramm!
#
# Hinweis: Lege zunächst fest, für welche Werte von $r$ du die Punkte zeichnen möchtest. Danach kannst du 100 zufällige Startpunkte 100 Iterationen laufen lassen und gucken, wo sie landen.

# %%
# Linspace für 50 gleich verteilte Punkte
r_werte = np.linspace(0,4)

# Startwerte
punkte = np.random.rand(len(r_werte), 100)

# Iterationen (Hinweis: Hier kannst du For-Schleifen verwenden)


# Plotkrams
plt.figure()
for r, p in zip(r_werte, punkte):
    plt.scatter(len(p)*[r], p, c="b", marker=".")
plt.grid()
plt.show()

# %% [markdown]
# Auf dieser [Website](http://walter.bislins.ch/blog/index.asp?page=Feigenbaum%2DDiagramm+erzeugen+und+analysieren) kannst du diverse Parameter (z.B. Anzahl der Iterationen und Wertepaare, die verschiedenen Wertebereiche usw.) variieren und so deren Auswirkung auf das Diagramm beobachten.
