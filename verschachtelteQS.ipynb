# %% [markdown]
# <a href="https://colab.research.google.com/github/ollihansen90/Mathe-SH/blob/main/verschachtelteQS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Verschachtelte Quersummen
#
# In diesem Notebook sollen verschachtelte Quersummen implementiert werden.
#
# ## 🧮 Was ist eine Quersumme?
#
# Die Quersumme einer Zahl erhält man, indem man alle Ziffern dieser Zahl miteinander verrechnet.
# Zum Beispiel:
#
# Die Quersumme von **123** ist **1 + 2 + 3 = 6**.
#
# Die Quersumme von **4057** ist **4 + 0 + 5 + 7 = 16**.
#
# In dieser Aufgabe soll genau diese Funktion programmiert werden. Wenn die Zahl nur eine Ziffer hat, wird sie einfach so zurückgegeben.

# %%
def quersumme(zahl):
    return zahl

print(quersumme(123)) # 6
print(quersumme(99)) # 18
print(quersumme(12829)) # 22

# %% [markdown]
# ## 🔁 Verschachtelte Quersummen
#
# Manchmal kann man die Quersumme **mehrmals hintereinander** berechnen.
# Beispiel:
#
# 1. Die Quersumme von **99** ist **9 + 9 = 18**.
#
# 2. Die Quersumme von **18** ist **8 + 1 = 9**.
#
# Jetzt ist das Ergebnis einstellig, wir sind also fertig.
#
# In dieser Aufgabe sollt genau das implementiert werden:
# Ihr berechnet zuerst die Quersumme einer Zahl. Wenn das Ergebnis **mehrstellig** ist, wird noch einmal die Quersumme davon berechnet, so lange, bis nur noch eine Ziffer übrig bleibt.
#
# So entsteht eine Funktion, die eine Zahl so lange "verkürzt", bis nur noch eine einzige Ziffer übrig ist.

# %%
def verschachtelung(zahl):
    return zahl

# %% [markdown]
# ## 📊 Quersummen für viele Zahlen
#
# Bisher habt ihr gelernt, wie man für eine
# **einzelne Zahl** die Quersumme (bzw. die mehrfach berechnete Quersumme) bestimmen kann.
# Jetzt wollen wir das Gleiche für **viele Zahlen** hintereinander machen, und zwar für alle Zahlen von **1 bis 1.000.000**!
#
# Dafür nutzen wir unsere Funktion für jede dieser Zahlen und berechnen, welche einzige Ziffer am Ende übrig bleibt, wenn man immer wieder die Quersumme bildet.
# Diese Ergebnisse speichern wir dann in einer Liste, damit wir sie später weiterverwenden oder auswerten können.
#
# So entsteht eine große Sammlung, in der für jede Zahl steht, auf welche Ziffer sie sich "zusammenfalten" lässt.

# %%
liste = 10*[0]

plt.figure()
plt.bar(list(range(10)), sumlist)
plt.grid()
plt.show()

# %% [markdown]
# ## ✖️ Von Quersummen zum Querprodukt
#
# Bisher habt ihr die Quersumme einer Zahl berechnet: also alle Ziffern addiert, bis nur noch eine Ziffer übrig blieb.
#
# Jetzt wollen wir etwas Neues ausprobieren:
# Statt die Ziffern zu addieren, werden sie diesmal miteinander multipliziert.
# Das nennt man ein Querprodukt.
#
# Beispiel:
# - Das Querprodukt von 234 ist **2 × 3 × 4 = 24**.
# - Wenn das Ergebnis wieder mehrstellig ist, kann man den Vorgang noch einmal wiederholen: **2 × 4 = 8**.
#
# Die Aufgabe ist also, die bisherige Quersummen-Funktion so anzupassen, dass sie statt der Summe das Produkt der Ziffern berechnet. Der Aufbau der Funktion bleibt dabei fast gleich.
