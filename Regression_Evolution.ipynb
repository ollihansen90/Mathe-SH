# %% [markdown]
# <a href="https://colab.research.google.com/github/ollihansen90/Mathe-SH/blob/main/Regression_Evolution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Maschinelles Lernen - Regression
# ## Genetischer Algorithmus
# ### Daten generieren

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)
data = np.random.randn(100,2)@np.array([[1,0],[1,1]])+np.array([1,2])

xlims = [np.floor(np.min(data[:,0]))-1, np.ceil(np.max(data[:,0]))+1]
ylims = [np.floor(np.min(data[:,1]))-1, np.ceil(np.max(data[:,1]))+1]

model = np.array([-1,4])
func = lambda x, m: m[0]*x+m[1]

def plot_model(model):
    plt.plot(xlims, func(np.array(xlims), model), "tab:orange")

def plot():
    plt.figure()
    plt.scatter(data[:,0], data[:,1])
    plot_model(model)
    plt.axis("scaled")
    plt.xlim(xlims)
    plt.ylim(ylims)
    plt.grid()
    plt.show()

plot()

# %% [markdown]
# ### Bestgerade

# %%
model = np.array([0,4])
plot()
